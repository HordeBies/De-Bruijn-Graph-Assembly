# %%
import json
import matplotlib.pyplot as plt

# %%
ypoints1 = []
ypoints2 = []
xpoints = []

def hms_to_m(s):
    t = 0
    for u in s.split(':'):
        t = 60 * t + int(u)
    return t / 60

for i in (5, 50, 250, 500, 750, 1050, 1063, 1067, 1069, 1070, 1075, 1100, 1250, 1500, 1750, 2000):
    date_time_obj = 0
    average_err = 0
    if i == 5:
        xpoints.append(i)
        df = json.load(open('Data/genom_k_' + str(i) + '_1.json'))
        date_time_obj += (hms_to_m(df['execution_time'][:8]))
        ypoints1.append(date_time_obj)
        average_err += df['error']    
        ypoints2.append(average_err)
    if i == 50:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error'] 
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 250:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 500:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 750:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1050:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1063:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1067:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1069:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1070:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1100:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1250:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1500:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 1750:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
    if i == 2000:
        xpoints.append(i)
        for k in range(1,6):
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            date_time_obj += (hms_to_m(df['execution_time'][:8]))
            average_err += df['error']
        ypoints2.append(average_err/k)
        ypoints1.append(date_time_obj/k)
           
fig, axs = plt.subplots(2,figsize=(15,15))
fig.suptitle('Average error and execution time graphs')
axs[0].plot(xpoints, ypoints1, color='r')
axs[0].set_title('Average Execution Time related to k-mers (min)', color='r')
axs[1].plot(xpoints, ypoints2, color='b')
axs[1].set_title('Average Error related to k-mers', color='r')
y_label = 'Average execution time(min)'
for ax in axs.flat:
    ax.set(xlabel='k-mer', ylabel=y_label)
    y_label = 'Average error'
for ax in axs.flat:
    ax.label_outer

# %%
ypoints1 = []
ypoints2 = []
xpoints = []

def hms_to_m(s):
    t = 0
    for u in s.split(':'):
        t = 60 * t + int(u)
    return t / 60

for i in (5, 50, 250, 500, 750, 1050, 1063, 1067, 1069, 1070, 1075, 1100, 1250, 1500, 1750, 2000):
    if i == 5:
        xpoints.append(i)
        df = json.load(open('Data/genom_k_' + str(i) + '_1.json'))
        ypoints1.append(hms_to_m(df['execution_time'][:8]))
        ypoints2.append(df['error'])
    if i == 50:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json')) 
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 250:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 500:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 750:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1050:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1063:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1067:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1069:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1070:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1100:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1250:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1500:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 1750:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))
    if i == 2000:
        for k in range(1,6):
            xpoints.append(i)
            df = json.load(open('Data/genom_k_' + str(i) + '_' + str(k) +'.json'))
            ypoints2.append(df['error'])
            ypoints1.append(hms_to_m(df['execution_time'][:8]))

fig, axs = plt.subplots(2,figsize=(15,15))
fig.suptitle('Average error and execution time graphs')
axs[0].scatter(xpoints, ypoints1, color='r')
axs[0].set_title('Average Execution Time related to k-mers (min)', color='r')
axs[1].scatter(xpoints, ypoints2, color='b')
axs[1].set_title('Average Error related to k-mers', color='r')
y_label = 'Average execution time(min)'
for ax in axs.flat:
    ax.set(xlabel='k-mer', ylabel=y_label)
    y_label = 'Average error'
for ax in axs.flat:
    ax.label_outer
